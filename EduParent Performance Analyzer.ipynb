# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/drive/MyDrive/Datasets/StudentsPerformance.csv")
df.head(50)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %% [markdown]
# Data Analysis

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ---

# %% [markdown]
# Adding a Column for total score in math , reading and writing

# %%
df["Total Score"] = df["math score"] + df["reading score"] + df["writing score"]
df.head(20)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %% [markdown]
# Adding a column of mean score in maths , reading and writing

# %%
df["Mean Score"] = ((df["Total Score"])/3).round()
df.head(20)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 12  female        group B                 high school      standard
# ...

# %% [markdown]
# Giving numeric form to parents education :
#
#   *   "0" for associate's degree
#   *   "1" for bachelor's degree
#   *   "2" for high school
#   *   "3" for master's degree
#   *   "4" for some college
#   *   "5" for some high school

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["parental level of education"] = le.fit_transform(df["parental level of education"])
df.head(20)
# Out:
#     gender race/ethnicity  parental level of education         lunch  \
# 0   female        group B                            1      standard
# 1   female        group C                            4      standard
# 2   female        group B                            3      standard
# 3     male        group A                            0  free/reduced
# 4     male        group C                            4      standard
# 5   female        group B                            0      standard
# 6   female        group B                            4      standard
# 7     male        group B                            4  free/reduced
# 8     male        group D                            2  free/reduced
# 9   female        group B                            2  free/reduced
# 10    male        group C                            0      standard
# 11    male        group D                            0      standard
# 12  female        group B                            2      standard
# ...

# %% [markdown]
# Stabilizing the connection between parental level of education and students grade(i.e Mean Score)

# %%
import seaborn as sns
sns.barplot(x = "parental level of education", y = "Mean Score", data = df)
# Out:
# <Axes: xlabel='parental level of education', ylabel='Mean Score'>

# %% [markdown]
# Outliers Detection

# %%
sns.boxplot(x = "Mean Score",data = df)
plt.show()

# %% [markdown]
# Correlation Analysis

# %%
corr_matrix = df.corr();
corr_matrix
# Out:
# <ipython-input-12-a882d5cabd78>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr();
#                              parental level of education  math score  \
# parental level of education                     1.000000   -0.068279
# math score                                     -0.068279    1.000000
# reading score                                  -0.072444    0.817580
# writing score                                  -0.084299    0.802642
# Total Score                                    -0.078883    0.918746
# Mean Score                                     -0.079944    0.918442
#
#                              reading score  writing score  Total Score  \
# parental level of education      -0.072444      -0.084299    -0.078883
# ...
